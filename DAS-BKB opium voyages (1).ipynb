# %%
import pandas as pd

# Specify the file path
file_path = '//Users/zhujiaqi/trifecta/BKB/das.xlsx'

# Read the Excel file into a DataFrame
df = pd.read_excel(file_path)

df
# Out:
# /var/folders/5g/vgjq024s5fgc9pf2fchw5m6c0000gn/T/ipykernel_2465/3328652404.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#                                                     url  voyId voyNumberDAS  \
# 0     http://resources.huygens.knaw.nl/das/detailVoy...  91055       0001.1
# 1     http://resources.huygens.knaw.nl/das/detailVoy...  91056       0002.1
# 2     http://resources.huygens.knaw.nl/das/detailVoy...  91057       0003.1
# 3     http://resources.huygens.knaw.nl/das/detailVoy...  91058       0004.1
# 4     http://resources.huygens.knaw.nl/das/detailVoy...  91059       0005.1
# ...

# %%
import pandas as pd

# Specify the file path
file_path = '//Users/zhujiaqi/trifecta/BKB/das.xlsx'

# Read all sheets into a dictionary of DataFrames
all_sheets = pd.read_excel(file_path, sheet_name=None)

# Display the names of the sheets
print("Sheet names:", all_sheets.keys())

# Access each DataFrame using the sheet name
for sheet_name, df in all_sheets.items():
    print(f"\nData from sheet: {sheet_name}")
    print(df.head())
# Out:
# Sheet names: dict_keys(['das_voyage', 'ship', 'shipNameVariant', 'shipType', 'master', 'onboard', 'yard', 'chamber', 'place'])
#
# Data from sheet: das_voyage
#                                                  url  voyId voyNumberDAS  \
# 0  http://resources.huygens.knaw.nl/das/detailVoy...  91055       0001.1
# 1  http://resources.huygens.knaw.nl/das/detailVoy...  91056       0002.1
# 2  http://resources.huygens.knaw.nl/das/detailVoy...  91057       0003.1
# 3  http://resources.huygens.knaw.nl/das/detailVoy...  91058       0004.1
# 4  http://resources.huygens.knaw.nl/das/detailVoy...  91059       0005.1
#
#    heenreis  terugreis        shipID     shipName  voyMasterID  \
# 0         1          0  DAS_ship0054  DAS_snv0056  das_mas2328
# 1         1          0  DAS_ship0337  DAS_snv0348  das_mas1789
# 2         1          0  DAS_ship0624  DAS_snv0643  das_mas1589
# 3         1          0  DAS_ship0953  DAS_snv0981  das_mas1868
# ...

# %%
# Read the specific sheets into DataFrames
DAS = pd.read_excel(file_path, sheet_name='das_voyage')
DAS_ship= pd.read_excel(file_path, sheet_name='ship')
DAS_shipNameVariant=pd.read_excel(file_path, sheet_name='shipNameVariant')
DAS_shipType = pd.read_excel(file_path, sheet_name='shipType')
DAS_master = pd.read_excel(file_path, sheet_name='master')
DAS_onboard =pd.read_excel(file_path, sheet_name='onboard')
DAS_yard = pd.read_excel(file_path, sheet_name='yard')
DAS_chamber = pd.read_excel(file_path, sheet_name='chamber')
DAS_place =pd.read_excel(file_path, sheet_name='place')

# %%
# Define the file path
import pandas as pd

file_path = 'file:///Users/zhujiaqi/trifecta/BKB/opium.csv'
    
# Read the TSV file without headers and specify column names
opium = pd.read_csv(file_path)
opium
# Out:
#       carId  carVoyageId  carProductId  carSpecificationId  carUnit  \
# 0    646738        99404          1142               781.0       69
# 1    646807        99410          1142               781.0       69
# 2    646995        99425          1142               659.0       67
# 3    647332        99449          1142               659.0       69
# 4    649969        99730          1142               659.0       67
# ..      ...          ...           ...                 ...      ...
# 193  894901       117790          1142                 NaN       69
# 194  894929       117791          1142                 NaN      257
# 195  894960       117792          1142                 NaN       69
# 196  894991       117793          1142                 NaN       69
# 197  902484       118190          1142             17054.0       69
#
#     carQuantity  carQuantityNumeric      carValue  carValueGuldens  \
# 0         4.359              4359.0    21.075,7,8          21075.0
# ...

# %%
# merge
opium_DAS = pd.merge(opium, DAS, left_on='voyageDAS', right_on='voyId')
opium_DAS
# Out:
#     carId  carVoyageId  carProductId  carSpecificationId  carUnit carQuantity  \
# 0  646738        99404          1142               781.0       69       4.359
# 1  646807        99410          1142               781.0       69       1.920
# 2  663416       101181          1142               781.0       69       1.319
# 3  663355       101170          1142               781.0       69         439
#
#    carQuantityNumeric    carValue  carValueGuldens  carValueStuivers  ...  \
# 0              4359.0  21.075,7,8          21075.0               7.0  ...
# 1              1920.0    9.279,50           9279.0               5.0  ...
# 2              1319.0    6.117,19           6117.0              19.0  ...
# 3               439.0  2.034,13,8           2034.0              13.0  ...
#
#    voyCapeDepartureEDTF_remark voyArrivalDateEDTF  voyArrivalDateEDTF_remark  \
# 0                          NaN         1780-01-11                        NaN
# ...

# %%
opium_DAS['voyChamberID']
# Out:
# 0    DAS_cham001
# 1    DAS_cham001
# 2    DAS_cham001
# 3    DAS_cham001
# Name: voyChamberID, dtype: object

# %%
### I. Which VOC chamber was involved in the opium trade?

# %%
# merge
opium_DAS_chamber = pd.merge(opium_DAS,DAS_chamber, left_on='voyChamberID', right_on='chamID')
opium_DAS
# Out:
#     carId  carVoyageId  carProductId  carSpecificationId  carUnit carQuantity  \
# 0  646738        99404          1142               781.0       69       4.359
# 1  646807        99410          1142               781.0       69       1.920
# 2  663416       101181          1142               781.0       69       1.319
# 3  663355       101170          1142               781.0       69         439
#
#    carQuantityNumeric    carValue  carValueGuldens  carValueStuivers  ...  \
# 0              4359.0  21.075,7,8          21075.0               7.0  ...
# 1              1920.0    9.279,50           9279.0               5.0  ...
# 2              1319.0    6.117,19           6117.0              19.0  ...
# 3               439.0  2.034,13,8           2034.0              13.0  ...
#
#    voyCapeDepartureEDTF_remark voyArrivalDateEDTF  voyArrivalDateEDTF_remark  \
# 0                          NaN         1780-01-11                        NaN
# ...

# %%
# merge
opium_DAS_chamber = pd.merge(opium_DAS,DAS_chamber, left_on='voyChamberID', right_on='chamID')
opium_DAS_chamber
# Out:
#     carId  carVoyageId  carProductId  carSpecificationId  carUnit carQuantity  \
# 0  646738        99404          1142               781.0       69       4.359
# 1  646807        99410          1142               781.0       69       1.920
# 2  663416       101181          1142               781.0       69       1.319
# 3  663355       101170          1142               781.0       69         439
#
#    carQuantityNumeric    carValue  carValueGuldens  carValueStuivers  ...  \
# 0              4359.0  21.075,7,8          21075.0               7.0  ...
# 1              1920.0    9.279,50           9279.0               5.0  ...
# 2              1319.0    6.117,19           6117.0              19.0  ...
# 3               439.0  2.034,13,8           2034.0              13.0  ...
#
#                                       voyParticulars voyCorrespondingNumber  \
# 0  The following data refer to the crew of the OV...                   8127
# ...

# %%
opium_DAS_chamber['chamberFullName']
# Out:
# 0    VOC Chamber Amsterdam
# 1    VOC Chamber Amsterdam
# 2    VOC Chamber Amsterdam
# 3    VOC Chamber Amsterdam
# Name: chamberFullName, dtype: object

# %%
opium_DAS['voyMasterID']
# Out:
# 0    das_mas0923
# 1    das_mas2516
# 2    das_mas1897
# 3    das_mas2149
# Name: voyMasterID, dtype: object

# %%
opium_DAS_master = pd.merge(opium_DAS,DAS_master, left_on='voyMasterID', right_on='voyMasterID')
opium_DAS_master['voyMasterLastName']
# Out:
# 0      Hansen
# 1    Steitsch
# 2      Mulder
# 3     Raatjes
# Name: voyMasterLastName, dtype: object

# %%
opium_DAS_master = pd.merge(opium_DAS,DAS_master, left_on='voyMasterID', right_on='voyMasterID')
opium_DAS_master['voyMasterLastName']
opium_DAS_master['voyMasterFirstName']
opium_DAS_master['voyMasterFamilyNamePrefix']
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# Name: voyMasterFamilyNamePrefix, dtype: object

# %%
opium_DAS_master = pd.merge(opium_DAS,DAS_master, left_on='voyMasterID', right_on='voyMasterID')
opium_DAS_master['voyMasterLastName']
# Out:
# 0      Hansen
# 1    Steitsch
# 2      Mulder
# 3     Raatjes
# Name: voyMasterLastName, dtype: object

# %%
opium_DAS_master['voyMasterFirstName']
# Out:
# 0            Hans
# 1         Hendrik
# 2        Gottlieb
# 3    Jan Frederik
# Name: voyMasterFirstName, dtype: object

# %%
opium_DAS_master['voyMasterFamilyNamePrefix']
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# Name: voyMasterFamilyNamePrefix, dtype: object

# %%
opium_DAS_master['voyMasterRemark']
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# Name: voyMasterRemark, dtype: object

# %%
# merge
opium_DAS_ship = pd.merge(opium_DAS,DAS_ship, left_on='shipID', right_on='shipID')
opium_DAS_ship
# Out:
#     carId  carVoyageId  carProductId  carSpecificationId  carUnit carQuantity  \
# 0  646738        99404          1142               781.0       69       4.359
# 1  646807        99410          1142               781.0       69       1.920
# 2  663416       101181          1142               781.0       69       1.319
# 3  663355       101170          1142               781.0       69         439
#
#    carQuantityNumeric    carValue  carValueGuldens  carValueStuivers  ...  \
# 0              4359.0  21.075,7,8          21075.0               7.0  ...
# 1              1920.0    9.279,50           9279.0               5.0  ...
# 2              1319.0    6.117,19           6117.0              19.0  ...
# 3               439.0  2.034,13,8           2034.0              13.0  ...
#
#    voyCorrespondingNumber voyRGPDeel  voymaster_VOCOPVid  voyTonnageMin  \
# 0                    8127        166                 NaN         1150.0
# ...

# %%
opium_DAS_ship['voyTonnageMin']
# Out:
# 0    1150.0
# 1    1150.0
# 2    1150.0
# 3    1150.0
# Name: voyTonnageMin, dtype: float64

# %%
# what are the maximum tonnage of these ships?
opium_DAS_ship['voyTonnageMax']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# Name: voyTonnageMax, dtype: float64

# %%
# when were these ships built?
opium_DAS_ship['voyBuilt']
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# Name: voyBuilt, dtype: object

# %%
#what are the type of these ships?
opium_DAS_ship['voyTypeOfShipID']
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# Name: voyTypeOfShipID, dtype: object

# %%
# what are the yard id for these ships?
opium_DAS_ship['voyYardYardID']
# Out:
# 0    DAS_yard006
# 1    DAS_yard006
# 2    DAS_yard001
# 3    DAS_yard001
# Name: voyYardYardID, dtype: object

# %%
# what are the shipIDs for these ships?
opium_DAS_ship['shipID']
# Out:
# 0    DAS_ship1139
# 1    DAS_ship1706
# 2    DAS_ship1463
# 3    DAS_ship0311
# Name: shipID, dtype: object

# %%
# merge
opium_DAS_ship_variant = pd.merge(opium_DAS,DAS_shipNameVariant, left_on='shipID', right_on='shipID')
opium_DAS_ship_variant
# Out:
#     carId  carVoyageId  carProductId  carSpecificationId  carUnit carQuantity  \
# 0  646738        99404          1142               781.0       69       4.359
# 1  646807        99410          1142               781.0       69       1.920
# 2  663416       101181          1142               781.0       69       1.319
# 3  663355       101170          1142               781.0       69         439
#
#    carQuantityNumeric    carValue  carValueGuldens  carValueStuivers  ...  \
# 0              4359.0  21.075,7,8          21075.0               7.0  ...
# 1              1920.0    9.279,50           9279.0               5.0  ...
# 2              1319.0    6.117,19           6117.0              19.0  ...
# 3               439.0  2.034,13,8           2034.0              13.0  ...
#
#    voyArrivalPlaceID voyInvoiceValue_y  voyChamber2ID  \
# 0          DAS_pl007               NaN            NaN
# 1          DAS_pl007               NaN            NaN
# ...

# %%
opium_DAS_ship_variant['shipNameVariantID']
# Out:
# 0    DAS_snv1169
# 1    DAS_snv1746
# 2    DAS_snv1500
# 3    DAS_snv0321
# Name: shipNameVariantID, dtype: object

# %%
# merge
opium_DAS_onboard = pd.merge(opium_DAS,DAS_onboard, left_on='carVoyageId', right_on='onbVoyageId')
opium_DAS_onboard
# Out:
# Empty DataFrame
# ...

# %%
# merge
opium_DAS_departure_place = pd.merge(opium_DAS,DAS_place, left_on='voyDeparturePlaceID', right_on='placeID')
opium_DAS_departure_place
# Out:
#     carId  carVoyageId  carProductId  carSpecificationId  carUnit carQuantity  \
# 0  646738        99404          1142               781.0       69       4.359
# 1  646807        99410          1142               781.0       69       1.920
# 2  663416       101181          1142               781.0       69       1.319
# 3  663355       101170          1142               781.0       69         439
#
#    carQuantityNumeric    carValue  carValueGuldens  carValueStuivers  ...  \
# 0              4359.0  21.075,7,8          21075.0               7.0  ...
# 1              1920.0    9.279,50           9279.0               5.0  ...
# 2              1319.0    6.117,19           6117.0              19.0  ...
# 3               439.0  2.034,13,8           2034.0              13.0  ...
#
#    voyInvoiceValue_y voyChamber2ID  \
# 0                NaN           NaN
# 1                NaN           NaN
# 2                NaN           NaN
# 3                NaN           NaN
#
# ...

# %%
opium_DAS_departure_place['toponym_original']
# Out:
# 0    Texel
# 1    Texel
# 2    Texel
# 3    Texel
# Name: toponym_original, dtype: object

# %%
opium_DAS_departure_place['toponym_standardized']
# Out:
# 0    Texel NL
# 1    Texel NL
# 2    Texel NL
# 3    Texel NL
# Name: toponym_standardized, dtype: object

# %%
# merge
opium_DAS_arrival_place = pd.merge(opium_DAS,DAS_place, left_on='voyArrivalPlaceID', right_on='placeID')
opium_DAS_arrival_place
# Out:
#     carId  carVoyageId  carProductId  carSpecificationId  carUnit carQuantity  \
# 0  646738        99404          1142               781.0       69       4.359
# 1  646807        99410          1142               781.0       69       1.920
# 2  663416       101181          1142               781.0       69       1.319
# 3  663355       101170          1142               781.0       69         439
#
#    carQuantityNumeric    carValue  carValueGuldens  carValueStuivers  ...  \
# 0              4359.0  21.075,7,8          21075.0               7.0  ...
# 1              1920.0    9.279,50           9279.0               5.0  ...
# 2              1319.0    6.117,19           6117.0              19.0  ...
# 3               439.0  2.034,13,8           2034.0              13.0  ...
#
#    voyInvoiceValue_y voyChamber2ID  \
# 0                NaN           NaN
# 1                NaN           NaN
# 2                NaN           NaN
# 3                NaN           NaN
#
# ...

# %%
opium_DAS_arrival_place['toponym_original']
# Out:
# 0    Batavia
# 1    Batavia
# 2    Batavia
# 3    Batavia
# Name: toponym_original, dtype: object

# %%
opium_DAS_arrival_place['toponym_standardized']
# Out:
# 0    Jakarta ID
# 1    Jakarta ID
# 2    Jakarta ID
# 3    Jakarta ID
# Name: toponym_standardized, dtype: object
